# %% [markdown]
# # Forest Plot
#
# Custom R function to generate forest plots. Available on https://osf.io/5y36r/files/mxndb. This jupyter notebook document is written to show how to use the custom R function in python.
#
# **CHANGELOG**:
#
# - [ ] write code in python
# - [ ] publish jupyter notebook document on GitHub.
# - [ ] add to portfolio section of CV/Resume.

# %%
import rpy2.robjects as ro
from rpy2.robjects.packages import importr

utils = importr('utils')
utils.chooseCRANmirror(ind=1)
from rpy2.robjects.vectors import StrVector

pkgs = (
    'googledrive',
    'googlesheets4',
    'readxl',
    'metafor',
    'dplyr',
    'meta',
    'ggplot2',
    'ggpubr',
    'ggforestplot',
    'ggplotify',
    'ggplot2',
    'tidyverse',
)

utils.install_packages(StrVector(pkgs))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import rpy2.robjects as ro
#       2 from rpy2.robjects.packages import importr
#       4 utils = importr('utils')
#
# ModuleNotFoundError: No module named 'rpy2'
